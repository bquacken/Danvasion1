# %%
import pygame
from settings import Settings
from ship import Ship
import game_functions as gf
from bullet import Bullet
from pygame.sprite import Group
from game_stats import GameStats
from button import Button
from scoreboard import Scoreboard
from bacon import Bacon

def run_game():
    #Intialize the game and create screen object
    pygame.init()
    ai_settings = Settings()
    screen = pygame.display.set_mode(
        (ai_settings.screen_width, ai_settings.screen_height))
    pygame.display.set_caption('Danvastion')
    
    #Play Button
    play_button = Button(ai_settings, screen, "Play")
    
    
    #Stats and Scoreboard
    stats = GameStats(ai_settings)
    sb = Scoreboard(ai_settings, screen, stats)
    
    #Make a ship
    ship = Ship(ai_settings, screen)
    #Make group to store bullets, aliens and bacon
    bullets = Group()
    aliens = Group()
    bacons = Group()
    
    #Create fleet of Aliens
    gf.create_fleet(ai_settings, screen, ship, aliens)
    
    #Set the background color
    bg_color = (230,230,230)
    running = True
    #Start Main Loop
    while running:
        #for event in pygame.event.get():
        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                        running =  False
            gf.check_events(ship, event, ai_settings, stats, sb, play_button,  bullets, screen, aliens)
        if stats.game_active:
            gf.update_ship(ship)
            gf.update_bullets(ai_settings, screen, stats, sb, ship, aliens, bullets)
            gf.update_aliens(ai_settings, stats, sb, screen, ship, aliens, bullets)
            #Delete old bullets
            for bullet in bullets.copy():
                if bullet.rect.bottom <= 0:
                    bullets.remove(bullet)
            #Delete old bacon
            for bacon in bacons.copy():
                if bacon.rect.bottom <= 0:
                    bacons.remove(bacon)
#Redraw the screen during each pass through the loop
        gf.update_screen(ai_settings, screen, stats, sb, ship, bullets, aliens, play_button, bacons)

    pygame.quit()
    quit()
run_game()
# Out:
# pygame 1.9.6
# Hello from the pygame community. https://www.pygame.org/contribute.html
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-ee66745d9ecf> in <module>
#      63     pygame.quit()
#      64     quit()
# ---> 65 run_game()
#
# <ipython-input-1-ee66745d9ecf> in run_game()
#      59                     bacons.remove(bacon)
#      60 #Redraw the screen during each pass through the loop
# ---> 61         gf.update_screen(ai_settings, screen, stats, sb, ship, bullets, aliens, play_button, bacons)
#      62
#      63     pygame.quit()
#
# ~/Python Practice/Danvasion/game_functions.py in update_screen(ai_settings, screen, stats, sb, ship, bullets, aliens, play_button, bacons)
#      68                         new_bacon = Bacon(ai_settings, screen, alien)
#      69                         bacons.add(new_bacon)
# ---> 70         update_bacon(ai_settings, stats, sb, screen, ship, aliens, bullets, bacons)
#      71         for bacon in bacons.sprites():
#      72                 bacon.draw_bacon()
#
# ~/Python Practice/Danvasion/game_functions.py in update_bacon(ai_settings, stats, sb, screen, ship, aliens, bullets, bacons)
#     164 def update_bacon(ai_settings, stats, sb, screen, ship, aliens, bullets, bacons):
#     165         bacons.update()
# --> 166         check_bacon_ship_collisions(ai_settings, stats, sb, screen, ship, aliens, bullets, bacons)
#     167
#     168 def check_bacon_ship_collisions(ai_settings, stats, sb, screen, ship, aliens, bullets, bacons):
#
# ~/Python Practice/Danvasion/game_functions.py in check_bacon_ship_collisions(ai_settings, stats, sb, screen, ship, aliens, bullets, bacons)
#     169         for bacon in bacons.sprites():
#     170                 if bacon.rect.colliderect(ship.rect):
# --> 171                         ship_hit(ai_settings, stats, sb, screen, ship, aliens, bullets)
#     172
#     173 def update_ship(ship):
#
# TypeError: ship_hit() missing 1 required positional argument: 'bacons'

# %%
# Out:
# <rect(0, 0, 54, 89)>
